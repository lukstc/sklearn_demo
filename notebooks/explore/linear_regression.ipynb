# %%
import os
import sys
import pandas as pd

# %%
for item in sys.path:
    print(item)
# Out:
# /Users/e0465278/Repo_local_personal/sklearn_demo/notebooks/explore
# /Users/e0465278/anaconda3/lib/python38.zip
# /Users/e0465278/anaconda3/lib/python3.8
# /Users/e0465278/anaconda3/lib/python3.8/lib-dynload
#
# /Users/e0465278/anaconda3/lib/python3.8/site-packages
# /Users/e0465278/anaconda3/lib/python3.8/site-packages/aeosa
# /Users/e0465278/anaconda3/lib/python3.8/site-packages/IPython/extensions
# /Users/e0465278/.ipython

# %%
sys.path.append('../')
sys.path.append('../../')

# %%
for item in sys.path:
    print(item)
# Out:
# /Users/e0465278/Repo_local_personal/sklearn_demo/notebooks/explore
# /Users/e0465278/anaconda3/lib/python38.zip
# /Users/e0465278/anaconda3/lib/python3.8
# /Users/e0465278/anaconda3/lib/python3.8/lib-dynload
#
# /Users/e0465278/anaconda3/lib/python3.8/site-packages
# /Users/e0465278/anaconda3/lib/python3.8/site-packages/aeosa
# /Users/e0465278/anaconda3/lib/python3.8/site-packages/IPython/extensions
# /Users/e0465278/.ipython
# ../
# ../
# ../../

# %%
print(os.getcwd())
# Out:
# /Users/e0465278/Repo_local_personal/sklearn_demo/notebooks/explore

# %%
iris = pd.read_csv("~/Repo_local_personal/sklearn_demo/data/raw/raw_iris_data.txt")

# %%
iris.drop(columns=["Unnamed: 0"],inplace=True)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %%
from sklearn.datasets import load_iris
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
X = iris[["sepal length (cm)","sepal width (cm)","petal length (cm)","petal width (cm)"]]

# %%
y = iris['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
StandardScaler().fit(X).transform(X)
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
pipe = make_pipeline(
    StandardScaler(),
    LogisticRegression()
)

# %%
X, y = load_iris(return_X_y=True)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
result = pipe.predict(X_test)

# %%
result
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2])

# %%
accuracy_score(result,y_test)
# Out:
# 0.9736842105263158
