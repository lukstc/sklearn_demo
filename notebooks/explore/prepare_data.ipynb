# %%
import os
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris(as_frame=True)

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
iris.frame
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris.frame.plot()

# %%
type(iris.frame)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.frame.to_csv(os.path.join('~/Repo_local_personal/sklearn_demo/data/raw','raw_iris_data.txt'))
